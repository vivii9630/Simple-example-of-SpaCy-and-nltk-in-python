# %%
import numpy as np
import pandas as pd

# %%
data = """Jayaram Jayalalithaa[a] (24 February 1948 – 5 December 2016) was an Indian politician and film actress who served six times as the Chief Minister of Tamil Nadu for over fourteen years between 1991 and 2016. From 9 February 1989, she was the general secretary of the All India Anna Dravida Munnetra Kazhagam (AIADMK), a Dravidian party whose cadre revered her as their "Amma" (mother) and Puratchi Thalaivi (revolutionary leader). Her critics in the media and the opposition accused her of fostering a personality cult and of demanding absolute loyalty from AIADMK legislators and ministers, who often publicly prostrated themselves before her.[3]

Jayalalithaa first came into prominence as a leading film actress in the mid-1960s. Though she had entered the profession reluctantly, upon the urging of her mother to support the family, Jayalalithaa worked prolifically. She appeared in 140 films between 1961 and 1980, primarily in the Tamil, Telugu and Kannada languages. Jayalalithaa received praise for her versatility as an actress and for her dancing skills, earning the sobriquet "Queen of Tamil Cinema".[4] Among her frequent co-stars was M. G. Ramachandran, a Tamil cultural icon who leveraged his immense popularity with the masses into a successful political career. In 1982, when MGR was chief minister, Jayalalithaa joined the AIADMK, the party he founded. Her political rise was rapid; within a few years she became AIADMK propaganda secretary and was elected to the Rajya Sabha, the upper house of India's Parliament. After MGR's death in 1987, Jayalalithaa proclaimed herself his political heir and, having fought off the faction headed by Janaki Ramachandran, MGR's widow, emerged as the sole leader of the AIADMK. Following the 1989 election, she became Leader of the Opposition to the DMK-led government headed by Karunanidhi, her bête noire.

In 1991 Jayalalithaa became chief minister, Tamil Nadu's youngest, for the first time. She earned a reputation for centralising state power among a coterie of bureaucrats; her council of ministers, whom she often shuffled around, were largely ceremonial in nature. The successful cradle-baby scheme, which enabled mothers to anonymously offer their newborns for adoption, emerged during this time. Despite an official salary of only a rupee a month, Jayalalithaa indulged in public displays of wealth, culminating in a lavish wedding for her foster son in 1995. In the 1996 election, the AIADMK was nearly wiped out at the hustings; Jayalalithaa herself lost her seat. The new Karunanidhi government filed several corruption cases against her, and she had to spend time in jail. Her fortunes revived in the 1998 general election, as the AIADMK became a key component of Prime Minister Atal Bihari Vajpayee's 1998–99 government; her withdrawal of support toppled it and triggered another general election just a year later.

The AIADMK returned to power in 2001, although Jayalalithaa was personally disbarred from contesting due to the corruption cases. Within a few months of her taking oath as chief minister, in September 2001, she was disqualified from holding office and forced to cede the chair to loyalist O. Panneerselvam. Upon her acquittal six months later, Jayalalithaa returned as chief minister to complete her term. Noted for its ruthlessness to political opponents, many of whom were arrested in midnight raids, her government grew unpopular. Another period (2006–11) in the opposition followed, before Jayalalithaa was sworn in as chief minister for the fourth time after the AIADMK swept the 2011 assembly election. Her government received attention for its extensive social-welfare agenda, which included several subsidised "Amma"-branded goods such as canteens, bottled water, salt and cement. Three years into her tenure, she was convicted in a disproportionate-assets case, rendering her disqualified to hold office. She returned as chief minister after being acquitted in May 2015. In the 2016 assembly election, she became the first Tamil Nadu chief minister since MGR in 1984 to be voted back into office. That September, she fell severely ill and, following 75 days of hospitalisation, died on 5 December 2016 due to cardiac arrest."""

# %%
import nltk
import re
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
lemmatizer = WordNetLemmatizer()
word = nltk.word_tokenize(data)

# %%
word
# Out:
# ['Jayaram',
#  'Jayalalithaa',
#  '[',
#  'a',
#  ']',
#  '(',
#  '24',
#  'February',
#  '1948',
#  '–',
#  '5',
#  'December',
#  '2016',
#  ')',
#  'was',
#  'an',
#  'Indian',
#  'politician',
#  'and',
#  'film',
#  'actress',
#  'who',
#  'served',
#  'six',
#  'times',
#  'as',
#  'the',
#  'Chief',
#  'Minister',
#  'of',
#  'Tamil',
#  'Nadu',
#  'for',
#  'over',
#  'fourteen',
#  'years',
#  'between',
#  '1991',
#  'and',
#  '2016',
#  '.',
#  'From',
#  '9',
#  'February',
#  '1989',
#  ',',
#  'she',
#  'was',
#  'the',
#  'general',
#  'secretary',
#  'of',
#  'the',
#  'All',
#  'India',
#  'Anna',
#  'Dravida',
#  'Munnetra',
#  'Kazhagam',
#  '(',
#  'AIADMK',
#  ')',
#  ',',
#  'a',
#  'Dravidian',
#  'party',
#  'whose',
#  'cadre',
#  'revered',
#  'her',
#  'as',
#  'their',
#  '``',
#  'Amma',
#  "''",
#  '(',
#  'mother',
#  ')',
#  'and',
#  'Puratchi',
#  'Thalaivi',
#  '(',
#  'revolutionary',
#  'leader',
#  ')',
#  '.',
#  'Her',
#  'critics',
#  'in',
#  'the',
#  'media',
#  'and',
#  'the',
#  'opposition',
#  'accused',
#  'her',
#  'of',
#  'fostering',
#  'a',
#  'personality',
#  'cult',
#  'and',
#  'of',
#  'demanding',
#  'absolute',
#  'loyalty',
#  'from',
#  'AIADMK',
#  'legislators',
#  'and',
#  'ministers',
#  ',',
#  'who',
#  'often',
#  'publicly',
#  'prostrated',
#  'themselves',
#  'before',
#  'her',
#  '.',
#  '[',
#  '3',
#  ']',
#  'Jayalalithaa',
#  'first',
#  'came',
#  'into',
#  'prominence',
#  'as',
#  'a',
#  'leading',
#  'film',
#  'actress',
#  'in',
#  'the',
#  'mid-1960s',
#  '.',
#  'Though',
#  'she',
#  'had',
#  'entered',
#  'the',
#  'profession',
#  'reluctantly',
#  ',',
#  'upon',
#  'the',
#  'urging',
#  'of',
#  'her',
#  'mother',
#  'to',
#  'support',
#  'the',
#  'family',
#  ',',
#  'Jayalalithaa',
#  'worked',
#  'prolifically',
#  '.',
#  'She',
#  'appeared',
#  'in',
#  '140',
#  'films',
#  'between',
#  '1961',
#  'and',
#  '1980',
#  ',',
#  'primarily',
#  'in',
#  'the',
#  'Tamil',
#  ',',
#  'Telugu',
#  'and',
#  'Kannada',
#  'languages',
#  '.',
#  'Jayalalithaa',
#  'received',
#  'praise',
#  'for',
#  'her',
#  'versatility',
#  'as',
#  'an',
#  'actress',
#  'and',
#  'for',
#  'her',
#  'dancing',
#  'skills',
#  ',',
#  'earning',
#  'the',
#  'sobriquet',
#  '``',
#  'Queen',
#  'of',
#  'Tamil',
#  'Cinema',
#  "''",
#  '.',
#  '[',
#  '4',
#  ']',
#  'Among',
#  'her',
#  'frequent',
#  'co-stars',
#  'was',
#  'M.',
#  'G.',
#  'Ramachandran',
#  ',',
#  'a',
#  'Tamil',
#  'cultural',
#  'icon',
#  'who',
#  'leveraged',
#  'his',
#  'immense',
#  'popularity',
#  'with',
#  'the',
#  'masses',
#  'into',
#  'a',
#  'successful',
#  'political',
#  'career',
#  '.',
#  'In',
#  '1982',
#  ',',
#  'when',
#  'MGR',
#  'was',
#  'chief',
#  'minister',
#  ',',
#  'Jayalalithaa',
#  'joined',
#  'the',
#  'AIADMK',
#  ',',
#  'the',
#  'party',
#  'he',
#  'founded',
#  '.',
#  'Her',
#  'political',
#  'rise',
#  'was',
#  'rapid',
#  ';',
#  'within',
#  'a',
#  'few',
#  'years',
#  'she',
#  'became',
#  'AIADMK',
#  'propaganda',
#  'secretary',
#  'and',
#  'was',
#  'elected',
#  'to',
#  'the',
#  'Rajya',
#  'Sabha',
#  ',',
#  'the',
#  'upper',
#  'house',
#  'of',
#  'India',
#  "'s",
#  'Parliament',
#  '.',
#  'After',
#  'MGR',
#  "'s",
#  'death',
#  'in',
#  '1987',
#  ',',
#  'Jayalalithaa',
#  'proclaimed',
#  'herself',
#  'his',
#  'political',
#  'heir',
#  'and',
#  ',',
#  'having',
#  'fought',
#  'off',
#  'the',
#  'faction',
#  'headed',
#  'by',
#  'Janaki',
#  'Ramachandran',
#  ',',
#  'MGR',
#  "'s",
#  'widow',
#  ',',
#  'emerged',
#  'as',
#  'the',
#  'sole',
#  'leader',
#  'of',
#  'the',
#  'AIADMK',
#  '.',
#  'Following',
#  'the',
#  '1989',
#  'election',
#  ',',
#  'she',
#  'became',
#  'Leader',
#  'of',
#  'the',
#  'Opposition',
#  'to',
#  'the',
#  'DMK-led',
#  'government',
#  'headed',
#  'by',
#  'Karunanidhi',
#  ',',
#  'her',
#  'bête',
#  'noire',
#  '.',
#  'In',
#  '1991',
#  'Jayalalithaa',
#  'became',
#  'chief',
#  'minister',
#  ',',
#  'Tamil',
#  'Nadu',
#  "'s",
#  'youngest',
#  ',',
#  'for',
#  'the',
#  'first',
#  'time',
#  '.',
#  'She',
#  'earned',
#  'a',
#  'reputation',
#  'for',
#  'centralising',
#  'state',
#  'power',
#  'among',
#  'a',
#  'coterie',
#  'of',
#  'bureaucrats',
#  ';',
#  'her',
#  'council',
#  'of',
#  'ministers',
#  ',',
#  'whom',
#  'she',
#  'often',
#  'shuffled',
#  'around',
#  ',',
#  'were',
#  'largely',
#  'ceremonial',
#  'in',
#  'nature',
#  '.',
#  'The',
#  'successful',
#  'cradle-baby',
#  'scheme',
#  ',',
#  'which',
#  'enabled',
#  'mothers',
#  'to',
#  'anonymously',
#  'offer',
#  'their',
#  'newborns',
#  'for',
#  'adoption',
#  ',',
#  'emerged',
#  'during',
#  'this',
#  'time',
#  '.',
#  'Despite',
#  'an',
#  'official',
#  'salary',
#  'of',
#  'only',
#  'a',
#  'rupee',
#  'a',
#  'month',
#  ',',
#  'Jayalalithaa',
#  'indulged',
#  'in',
#  'public',
#  'displays',
#  'of',
#  'wealth',
#  ',',
#  'culminating',
#  'in',
#  'a',
#  'lavish',
#  'wedding',
#  'for',
#  'her',
#  'foster',
#  'son',
#  'in',
#  '1995',
#  '.',
#  'In',
#  'the',
#  '1996',
#  'election',
#  ',',
#  'the',
#  'AIADMK',
#  'was',
#  'nearly',
#  'wiped',
#  'out',
#  'at',
#  'the',
#  'hustings',
#  ';',
#  'Jayalalithaa',
#  'herself',
#  'lost',
#  'her',
#  'seat',
#  '.',
#  'The',
#  'new',
#  'Karunanidhi',
#  'government',
#  'filed',
#  'several',
#  'corruption',
#  'cases',
#  'against',
#  'her',
#  ',',
#  'and',
#  'she',
#  'had',
#  'to',
#  'spend',
#  'time',
#  'in',
#  'jail',
#  '.',
#  'Her',
#  'fortunes',
#  'revived',
#  'in',
#  'the',
#  '1998',
#  'general',
#  'election',
#  ',',
#  'as',
#  'the',
#  'AIADMK',
#  'became',
#  'a',
#  'key',
#  'component',
#  'of',
#  'Prime',
#  'Minister',
#  'Atal',
#  'Bihari',
#  'Vajpayee',
#  "'s",
#  '1998–99',
#  'government',
#  ';',
#  'her',
#  'withdrawal',
#  'of',
#  'support',
#  'toppled',
#  'it',
#  'and',
#  'triggered',
#  'another',
#  'general',
#  'election',
#  'just',
#  'a',
#  'year',
#  'later',
#  '.',
#  'The',
#  'AIADMK',
#  'returned',
#  'to',
#  'power',
#  'in',
#  '2001',
#  ',',
#  'although',
#  'Jayalalithaa',
#  'was',
#  'personally',
#  'disbarred',
#  'from',
#  'contesting',
#  'due',
#  'to',
#  'the',
#  'corruption',
#  'cases',
#  '.',
#  'Within',
#  'a',
#  'few',
#  'months',
#  'of',
#  'her',
#  'taking',
#  'oath',
#  'as',
#  'chief',
#  'minister',
#  ',',
#  'in',
#  'September',
#  '2001',
#  ',',
#  'she',
#  'was',
#  'disqualified',
#  'from',
#  'holding',
#  'office',
#  'and',
#  'forced',
#  'to',
#  'cede',
#  'the',
#  'chair',
#  'to',
#  'loyalist',
#  'O.',
#  'Panneerselvam',
#  '.',
#  'Upon',
#  'her',
#  'acquittal',
#  'six',
#  'months',
#  'later',
#  ',',
#  'Jayalalithaa',
#  'returned',
#  'as',
#  'chief',
#  'minister',
#  'to',
#  'complete',
#  'her',
#  'term',
#  '.',
#  'Noted',
#  'for',
#  'its',
#  'ruthlessness',
#  'to',
#  'political',
#  'opponents',
#  ',',
#  'many',
#  'of',
#  'whom',
#  'were',
#  'arrested',
#  'in',
#  'midnight',
#  'raids',
#  ',',
#  'her',
#  'government',
#  'grew',
#  'unpopular',
#  '.',
#  'Another',
#  'period',
#  '(',
#  '2006–11',
#  ')',
#  'in',
#  'the',
#  'opposition',
#  'followed',
#  ',',
#  'before',
#  'Jayalalithaa',
#  'was',
#  'sworn',
#  'in',
#  'as',
#  'chief',
#  'minister',
#  'for',
#  'the',
#  'fourth',
#  'time',
#  'after',
#  'the',
#  'AIADMK',
#  'swept',
#  'the',
#  '2011',
#  'assembly',
#  'election',
#  '.',
#  'Her',
#  'government',
#  'received',
#  'attention',
#  'for',
#  'its',
#  'extensive',
#  'social-welfare',
#  'agenda',
#  ',',
#  'which',
#  'included',
#  'several',
#  'subsidised',
#  '``',
#  'Amma',
#  "''",
#  '-branded',
#  'goods',
#  'such',
#  'as',
#  'canteens',
#  ',',
#  'bottled',
#  'water',
#  ',',
#  'salt',
#  'and',
#  'cement',
#  '.',
#  'Three',
#  'years',
#  'into',
#  'her',
#  'tenure',
#  ',',
#  'she',
#  'was',
#  'convicted',
#  'in',
#  'a',
#  'disproportionate-assets',
#  'case',
#  ',',
#  'rendering',
#  'her',
#  'disqualified',
#  'to',
#  'hold',
#  'office',
#  '.',
#  'She',
#  'returned',
#  'as',
#  'chief',
#  'minister',
#  'after',
#  'being',
#  'acquitted',
#  'in',
#  'May',
#  '2015',
#  '.',
#  'In',
#  'the',
#  '2016',
#  'assembly',
#  'election',
#  ',',
#  'she',
#  'became',
#  'the',
#  'first',
#  'Tamil',
#  'Nadu',
#  'chief',
#  'minister',
#  'since',
#  'MGR',
#  'in',
#  '1984',
#  'to',
#  'be',
#  'voted',
#  'back',
#  'into',
#  'office',
#  '.',
#  'That',
#  'September',
#  ',',
#  'she',
#  'fell',
#  'severely',
#  'ill',
#  'and',
#  ',',
#  'following',
#  '75',
#  'days',
#  'of',
#  'hospitalisation',
#  ',',
#  'died',
#  'on',
#  '5',
#  'December',
#  '2016',
#  'due',
#  'to',
#  'cardiac',
#  'arrest',
#  '.']

# %%
pos = nltk.pos_tag(word)
pos
# Out:
# [('Jayaram', 'NNP'),
#  ('Jayalalithaa', 'NNP'),
#  ('[', 'VBZ'),
#  ('a', 'DT'),
#  (']', 'NN'),
#  ('(', '('),
#  ('24', 'CD'),
#  ('February', 'NNP'),
#  ('1948', 'CD'),
#  ('–', 'NNP'),
#  ('5', 'CD'),
#  ('December', 'NNP'),
#  ('2016', 'CD'),
#  (')', ')'),
#  ('was', 'VBD'),
#  ('an', 'DT'),
#  ('Indian', 'JJ'),
#  ('politician', 'NN'),
#  ('and', 'CC'),
#  ('film', 'NN'),
#  ('actress', 'NN'),
#  ('who', 'WP'),
#  ('served', 'VBD'),
#  ('six', 'CD'),
#  ('times', 'NNS'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('Chief', 'NNP'),
#  ('Minister', 'NNP'),
#  ('of', 'IN'),
#  ('Tamil', 'NNP'),
#  ('Nadu', 'NNP'),
#  ('for', 'IN'),
#  ('over', 'IN'),
#  ('fourteen', 'JJ'),
#  ('years', 'NNS'),
#  ('between', 'IN'),
#  ('1991', 'CD'),
#  ('and', 'CC'),
#  ('2016', 'CD'),
#  ('.', '.'),
#  ('From', 'IN'),
#  ('9', 'CD'),
#  ('February', 'NNP'),
#  ('1989', 'CD'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('general', 'JJ'),
#  ('secretary', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('All', 'NNP'),
#  ('India', 'NNP'),
#  ('Anna', 'NNP'),
#  ('Dravida', 'NNP'),
#  ('Munnetra', 'NNP'),
#  ('Kazhagam', 'NNP'),
#  ('(', '('),
#  ('AIADMK', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('a', 'DT'),
#  ('Dravidian', 'NNP'),
#  ('party', 'NN'),
#  ('whose', 'WP$'),
#  ('cadre', 'NN'),
#  ('revered', 'VBD'),
#  ('her', 'PRP'),
#  ('as', 'IN'),
#  ('their', 'PRP$'),
#  ('``', '``'),
#  ('Amma', 'NNP'),
#  ("''", "''"),
#  ('(', '('),
#  ('mother', 'NN'),
#  (')', ')'),
#  ('and', 'CC'),
#  ('Puratchi', 'NNP'),
#  ('Thalaivi', 'NNP'),
#  ('(', '('),
#  ('revolutionary', 'JJ'),
#  ('leader', 'NN'),
#  (')', ')'),
#  ('.', '.'),
#  ('Her', 'PRP$'),
#  ('critics', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('media', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('opposition', 'NN'),
#  ('accused', 'VBD'),
#  ('her', 'PRP$'),
#  ('of', 'IN'),
#  ('fostering', 'VBG'),
#  ('a', 'DT'),
#  ('personality', 'NN'),
#  ('cult', 'NN'),
#  ('and', 'CC'),
#  ('of', 'IN'),
#  ('demanding', 'VBG'),
#  ('absolute', 'JJ'),
#  ('loyalty', 'NN'),
#  ('from', 'IN'),
#  ('AIADMK', 'NNP'),
#  ('legislators', 'NNS'),
#  ('and', 'CC'),
#  ('ministers', 'NNS'),
#  (',', ','),
#  ('who', 'WP'),
#  ('often', 'RB'),
#  ('publicly', 'RB'),
#  ('prostrated', 'VBN'),
#  ('themselves', 'PRP'),
#  ('before', 'IN'),
#  ('her', 'PRP'),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('3', 'CD'),
#  (']', 'NNP'),
#  ('Jayalalithaa', 'NNP'),
#  ('first', 'RB'),
#  ('came', 'VBD'),
#  ('into', 'IN'),
#  ('prominence', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('leading', 'JJ'),
#  ('film', 'NN'),
#  ('actress', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('mid-1960s', 'NN'),
#  ('.', '.'),
#  ('Though', 'IN'),
#  ('she', 'PRP'),
#  ('had', 'VBD'),
#  ('entered', 'VBN'),
#  ('the', 'DT'),
#  ('profession', 'NN'),
#  ('reluctantly', 'RB'),
#  (',', ','),
#  ('upon', 'IN'),
#  ('the', 'DT'),
#  ('urging', 'NN'),
#  ('of', 'IN'),
#  ('her', 'PRP$'),
#  ('mother', 'NN'),
#  ('to', 'TO'),
#  ('support', 'VB'),
#  ('the', 'DT'),
#  ('family', 'NN'),
#  (',', ','),
#  ('Jayalalithaa', 'NNP'),
#  ('worked', 'VBD'),
#  ('prolifically', 'RB'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('appeared', 'VBD'),
#  ('in', 'IN'),
#  ('140', 'CD'),
#  ('films', 'NNS'),
#  ('between', 'IN'),
#  ('1961', 'CD'),
#  ('and', 'CC'),
#  ('1980', 'CD'),
#  (',', ','),
#  ('primarily', 'RB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Tamil', 'NNP'),
#  (',', ','),
#  ('Telugu', 'NNP'),
#  ('and', 'CC'),
#  ('Kannada', 'NNP'),
#  ('languages', 'NNS'),
#  ('.', '.'),
#  ('Jayalalithaa', 'NNP'),
#  ('received', 'VBD'),
#  ('praise', 'NN'),
#  ('for', 'IN'),
#  ('her', 'PRP$'),
#  ('versatility', 'NN'),
#  ('as', 'IN'),
#  ('an', 'DT'),
#  ('actress', 'NN'),
#  ('and', 'CC'),
#  ('for', 'IN'),
#  ('her', 'PRP$'),
#  ('dancing', 'NN'),
#  ('skills', 'NNS'),
#  (',', ','),
#  ('earning', 'VBG'),
#  ('the', 'DT'),
#  ('sobriquet', 'NN'),
#  ('``', '``'),
#  ('Queen', 'NNP'),
#  ('of', 'IN'),
#  ('Tamil', 'NNP'),
#  ('Cinema', 'NNP'),
#  ("''", "''"),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('4', 'CD'),
#  (']', 'NN'),
#  ('Among', 'IN'),
#  ('her', 'PRP$'),
#  ('frequent', 'JJ'),
#  ('co-stars', 'NNS'),
#  ('was', 'VBD'),
#  ('M.', 'NNP'),
#  ('G.', 'NNP'),
#  ('Ramachandran', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('Tamil', 'NNP'),
#  ('cultural', 'JJ'),
#  ('icon', 'NN'),
#  ('who', 'WP'),
#  ('leveraged', 'VBD'),
#  ('his', 'PRP$'),
#  ('immense', 'JJ'),
#  ('popularity', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('masses', 'NNS'),
#  ('into', 'IN'),
#  ('a', 'DT'),
#  ('successful', 'JJ'),
#  ('political', 'JJ'),
#  ('career', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('1982', 'CD'),
#  (',', ','),
#  ('when', 'WRB'),
#  ('MGR', 'NNP'),
#  ('was', 'VBD'),
#  ('chief', 'JJ'),
#  ('minister', 'NN'),
#  (',', ','),
#  ('Jayalalithaa', 'NNP'),
#  ('joined', 'VBD'),
#  ('the', 'DT'),
#  ('AIADMK', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('party', 'NN'),
#  ('he', 'PRP'),
#  ('founded', 'VBD'),
#  ('.', '.'),
#  ('Her', 'PRP$'),
#  ('political', 'JJ'),
#  ('rise', 'NN'),
#  ('was', 'VBD'),
#  ('rapid', 'JJ'),
#  (';', ':'),
#  ('within', 'IN'),
#  ('a', 'DT'),
#  ('few', 'JJ'),
#  ('years', 'NNS'),
#  ('she', 'PRP'),
#  ('became', 'VBD'),
#  ('AIADMK', 'NNP'),
#  ('propaganda', 'NN'),
#  ('secretary', 'NN'),
#  ('and', 'CC'),
#  ('was', 'VBD'),
#  ('elected', 'VBN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('Rajya', 'NNP'),
#  ('Sabha', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('upper', 'JJ'),
#  ('house', 'NN'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  ("'s", 'POS'),
#  ('Parliament', 'NNP'),
#  ('.', '.'),
#  ('After', 'IN'),
#  ('MGR', 'NNP'),
#  ("'s", 'POS'),
#  ('death', 'NN'),
#  ('in', 'IN'),
#  ('1987', 'CD'),
#  (',', ','),
#  ('Jayalalithaa', 'NNP'),
#  ('proclaimed', 'VBD'),
#  ('herself', 'PRP'),
#  ('his', 'PRP$'),
#  ('political', 'JJ'),
#  ('heir', 'NN'),
#  ('and', 'CC'),
#  (',', ','),
#  ('having', 'VBG'),
#  ('fought', 'VBN'),
#  ('off', 'RP'),
#  ('the', 'DT'),
#  ('faction', 'NN'),
#  ('headed', 'VBN'),
#  ('by', 'IN'),
#  ('Janaki', 'NNP'),
#  ('Ramachandran', 'NNP'),
#  (',', ','),
#  ('MGR', 'NNP'),
#  ("'s", 'POS'),
#  ('widow', 'NN'),
#  (',', ','),
#  ('emerged', 'VBD'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('sole', 'JJ'),
#  ('leader', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('AIADMK', 'NNP'),
#  ('.', '.'),
#  ('Following', 'VBG'),
#  ('the', 'DT'),
#  ('1989', 'CD'),
#  ('election', 'NN'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('became', 'VBD'),
#  ('Leader', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Opposition', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('DMK-led', 'JJ'),
#  ('government', 'NN'),
#  ('headed', 'VBN'),
#  ('by', 'IN'),
#  ('Karunanidhi', 'NNP'),
#  (',', ','),
#  ('her', 'PRP$'),
#  ('bête', 'NN'),
#  ('noire', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('1991', 'CD'),
#  ('Jayalalithaa', 'NNP'),
#  ('became', 'VBD'),
#  ('chief', 'JJ'),
#  ('minister', 'NN'),
#  (',', ','),
#  ('Tamil', 'NNP'),
#  ('Nadu', 'NNP'),
#  ("'s", 'POS'),
#  ('youngest', 'JJS'),
#  (',', ','),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('earned', 'VBD'),
#  ('a', 'DT'),
#  ('reputation', 'NN'),
#  ('for', 'IN'),
#  ('centralising', 'VBG'),
#  ('state', 'NN'),
#  ('power', 'NN'),
#  ('among', 'IN'),
#  ('a', 'DT'),
#  ('coterie', 'NN'),
#  ('of', 'IN'),
#  ('bureaucrats', 'NNS'),
#  (';', ':'),
#  ('her', 'PRP$'),
#  ('council', 'NN'),
#  ('of', 'IN'),
#  ('ministers', 'NNS'),
#  (',', ','),
#  ('whom', 'WP'),
#  ('she', 'PRP'),
#  ('often', 'RB'),
#  ('shuffled', 'VBD'),
#  ('around', 'RB'),
#  (',', ','),
#  ('were', 'VBD'),
#  ('largely', 'RB'),
#  ('ceremonial', 'JJ'),
#  ('in', 'IN'),
#  ('nature', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('successful', 'JJ'),
#  ('cradle-baby', 'JJ'),
#  ('scheme', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('enabled', 'VBD'),
#  ('mothers', 'NNS'),
#  ('to', 'TO'),
#  ('anonymously', 'RB'),
#  ('offer', 'VB'),
#  ('their', 'PRP$'),
#  ('newborns', 'NNS'),
#  ('for', 'IN'),
#  ('adoption', 'NN'),
#  (',', ','),
#  ('emerged', 'VBD'),
#  ('during', 'IN'),
#  ('this', 'DT'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('Despite', 'IN'),
#  ('an', 'DT'),
#  ('official', 'JJ'),
#  ('salary', 'NN'),
#  ('of', 'IN'),
#  ('only', 'RB'),
#  ('a', 'DT'),
#  ('rupee', 'NN'),
#  ('a', 'DT'),
#  ('month', 'NN'),
#  (',', ','),
#  ('Jayalalithaa', 'NNP'),
#  ('indulged', 'VBD'),
#  ('in', 'IN'),
#  ('public', 'JJ'),
#  ('displays', 'NNS'),
#  ('of', 'IN'),
#  ('wealth', 'NN'),
#  (',', ','),
#  ('culminating', 'VBG'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('lavish', 'JJ'),
#  ('wedding', 'NN'),
#  ('for', 'IN'),
#  ('her', 'PRP$'),
#  ('foster', 'JJ'),
#  ('son', 'NN'),
#  ('in', 'IN'),
#  ('1995', 'CD'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('1996', 'CD'),
#  ('election', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('AIADMK', 'NNP'),
#  ('was', 'VBD'),
#  ('nearly', 'RB'),
#  ('wiped', 'VBN'),
#  ('out', 'RP'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('hustings', 'NNS'),
#  (';', ':'),
#  ('Jayalalithaa', 'NNP'),
#  ('herself', 'PRP'),
#  ('lost', 'VBD'),
#  ('her', 'PRP'),
#  ('seat', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('new', 'JJ'),
#  ('Karunanidhi', 'NNP'),
#  ('government', 'NN'),
#  ('filed', 'VBD'),
#  ('several', 'JJ'),
#  ('corruption', 'NN'),
#  ('cases', 'NNS'),
#  ('against', 'IN'),
#  ('her', 'PRP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('she', 'PRP'),
#  ('had', 'VBD'),
#  ('to', 'TO'),
#  ('spend', 'VB'),
#  ('time', 'NN'),
#  ('in', 'IN'),
#  ('jail', 'NN'),
#  ('.', '.'),
#  ('Her', 'PRP$'),
#  ('fortunes', 'NNS'),
#  ('revived', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('1998', 'CD'),
#  ('general', 'JJ'),
#  ('election', 'NN'),
#  (',', ','),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('AIADMK', 'NNP'),
#  ('became', 'VBD'),
#  ('a', 'DT'),
#  ('key', 'JJ'),
#  ('component', 'NN'),
#  ('of', 'IN'),
#  ('Prime', 'NNP'),
#  ('Minister', 'NNP'),
#  ('Atal', 'NNP'),
#  ('Bihari', 'NNP'),
#  ('Vajpayee', 'NNP'),
#  ("'s", 'POS'),
#  ('1998–99', 'CD'),
#  ('government', 'NN'),
#  (';', ':'),
#  ('her', 'PRP$'),
#  ('withdrawal', 'NN'),
#  ('of', 'IN'),
#  ('support', 'NN'),
#  ('toppled', 'VBD'),
#  ('it', 'PRP'),
#  ('and', 'CC'),
#  ('triggered', 'VBD'),
#  ('another', 'DT'),
#  ('general', 'JJ'),
#  ('election', 'NN'),
#  ('just', 'RB'),
#  ('a', 'DT'),
#  ('year', 'NN'),
#  ('later', 'RB'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('AIADMK', 'NNP'),
#  ('returned', 'VBD'),
#  ('to', 'TO'),
#  ('power', 'NN'),
#  ('in', 'IN'),
#  ('2001', 'CD'),
#  (',', ','),
#  ('although', 'IN'),
#  ('Jayalalithaa', 'NNP'),
#  ('was', 'VBD'),
#  ('personally', 'RB'),
#  ('disbarred', 'VBN'),
#  ('from', 'IN'),
#  ('contesting', 'VBG'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('corruption', 'NN'),
#  ('cases', 'NNS'),
#  ('.', '.'),
#  ('Within', 'IN'),
#  ('a', 'DT'),
#  ('few', 'JJ'),
#  ('months', 'NNS'),
#  ('of', 'IN'),
#  ('her', 'PRP$'),
#  ('taking', 'VBG'),
#  ('oath', 'NN'),
#  ('as', 'IN'),
#  ('chief', 'JJ'),
#  ('minister', 'NN'),
#  (',', ','),
#  ('in', 'IN'),
#  ('September', 'NNP'),
#  ('2001', 'CD'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('disqualified', 'VBN'),
#  ('from', 'IN'),
#  ('holding', 'VBG'),
#  ('office', 'NN'),
#  ('and', 'CC'),
#  ('forced', 'VBN'),
#  ('to', 'TO'),
#  ('cede', 'VB'),
#  ('the', 'DT'),
#  ('chair', 'NN'),
#  ('to', 'TO'),
#  ('loyalist', 'VB'),
#  ('O.', 'NNP'),
#  ('Panneerselvam', 'NNP'),
#  ('.', '.'),
#  ('Upon', 'IN'),
#  ('her', 'PRP$'),
#  ('acquittal', 'JJ'),
#  ('six', 'CD'),
#  ('months', 'NNS'),
#  ('later', 'RB'),
#  (',', ','),
#  ('Jayalalithaa', 'NNP'),
#  ('returned', 'VBD'),
#  ('as', 'IN'),
#  ('chief', 'NN'),
#  ('minister', 'NN'),
#  ('to', 'TO'),
#  ('complete', 'VB'),
#  ('her', 'PRP$'),
#  ('term', 'NN'),
#  ('.', '.'),
#  ('Noted', 'VBN'),
#  ('for', 'IN'),
#  ('its', 'PRP$'),
#  ('ruthlessness', 'NN'),
#  ('to', 'TO'),
#  ('political', 'JJ'),
#  ('opponents', 'NNS'),
#  (',', ','),
#  ('many', 'JJ'),
#  ('of', 'IN'),
#  ('whom', 'WP'),
#  ('were', 'VBD'),
#  ('arrested', 'VBN'),
#  ('in', 'IN'),
#  ('midnight', 'NN'),
#  ('raids', 'NNS'),
#  (',', ','),
#  ('her', 'PRP$'),
#  ('government', 'NN'),
#  ('grew', 'VBD'),
#  ('unpopular', 'JJ'),
#  ('.', '.'),
#  ('Another', 'DT'),
#  ('period', 'NN'),
#  ('(', '('),
#  ('2006–11', 'CD'),
#  (')', ')'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('opposition', 'NN'),
#  ('followed', 'VBD'),
#  (',', ','),
#  ('before', 'IN'),
#  ('Jayalalithaa', 'NNP'),
#  ('was', 'VBD'),
#  ('sworn', 'VBN'),
#  ('in', 'IN'),
#  ('as', 'RB'),
#  ('chief', 'JJ'),
#  ('minister', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('fourth', 'JJ'),
#  ('time', 'NN'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('AIADMK', 'NNP'),
#  ('swept', 'VBD'),
#  ('the', 'DT'),
#  ('2011', 'CD'),
#  ('assembly', 'NN'),
#  ('election', 'NN'),
#  ('.', '.'),
#  ('Her', 'PRP$'),
#  ('government', 'NN'),
#  ('received', 'VBD'),
#  ('attention', 'NN'),
#  ('for', 'IN'),
#  ('its', 'PRP$'),
#  ('extensive', 'JJ'),
#  ('social-welfare', 'JJ'),
#  ('agenda', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('included', 'VBD'),
#  ('several', 'JJ'),
#  ('subsidised', 'VBN'),
#  ('``', '``'),
#  ('Amma', 'NNP'),
#  ("''", "''"),
#  ('-branded', 'VBD'),
#  ('goods', 'NNS'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('canteens', 'NNS'),
#  (',', ','),
#  ('bottled', 'VBD'),
#  ('water', 'NN'),
#  (',', ','),
#  ('salt', 'NN'),
#  ('and', 'CC'),
#  ('cement', 'NN'),
#  ('.', '.'),
#  ('Three', 'CD'),
#  ('years', 'NNS'),
#  ('into', 'IN'),
#  ('her', 'PRP$'),
#  ('tenure', 'NN'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('convicted', 'VBN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('disproportionate-assets', 'JJ'),
#  ('case', 'NN'),
#  (',', ','),
#  ('rendering', 'VBG'),
#  ('her', 'PRP$'),
#  ('disqualified', 'VBN'),
#  ('to', 'TO'),
#  ('hold', 'VB'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('returned', 'VBD'),
#  ('as', 'IN'),
#  ('chief', 'NN'),
#  ('minister', 'NN'),
#  ('after', 'IN'),
#  ('being', 'VBG'),
#  ('acquitted', 'VBN'),
#  ('in', 'IN'),
#  ('May', 'NNP'),
#  ('2015', 'CD'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('2016', 'CD'),
#  ('assembly', 'NN'),
#  ('election', 'NN'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('became', 'VBD'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('Tamil', 'NNP'),
#  ('Nadu', 'NNP'),
#  ('chief', 'JJ'),
#  ('minister', 'NN'),
#  ('since', 'IN'),
#  ('MGR', 'NNP'),
#  ('in', 'IN'),
#  ('1984', 'CD'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('voted', 'VBN'),
#  ('back', 'RB'),
#  ('into', 'IN'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('That', 'IN'),
#  ('September', 'NNP'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('fell', 'VBD'),
#  ('severely', 'RB'),
#  ('ill', 'JJ'),
#  ('and', 'CC'),
#  (',', ','),
#  ('following', 'VBG'),
#  ('75', 'CD'),
#  ('days', 'NNS'),
#  ('of', 'IN'),
#  ('hospitalisation', 'NN'),
#  (',', ','),
#  ('died', 'VBD'),
#  ('on', 'IN'),
#  ('5', 'CD'),
#  ('December', 'NNP'),
#  ('2016', 'CD'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('cardiac', 'JJ'),
#  ('arrest', 'NN'),
#  ('.', '.')]

# %%
nltk.help.upenn_tagset('CD')
# Out:
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...

# %%
name_labels = nltk.ne_chunk(pos, binary = True)
name_labels
entity = []
labels = []
for n in name_labels:
    if hasattr(n,'label'):
        entity.append(' '.join([i[0] for i in n]))
        labels.append(n.label())

entity_df = list(set(zip(entity, labels)))
df = pd.DataFrame(entity_df)
df
# Out:
#                        0   1
# 0                 Indian  NE
# 1                  Tamil  NE
# 2                Kannada  NE
# 3   Atal Bihari Vajpayee  NE
# 4                 AIADMK  NE
# 5           Jayalalithaa  NE
# 6                    MGR  NE
# 7   Jayaram Jayalalithaa  NE
# 8              Dravidian  NE
# 9      Puratchi Thalaivi  NE
# 10                Telugu  NE
# 11            Tamil Nadu  NE
# 12          Tamil Cinema  NE
# 13   Janaki Ramachandran  NE
# 14           Karunanidhi  NE
# 15                 India  NE
# 16           Rajya Sabha  NE

# %%
specific_name = nltk.ne_chunk(pos, binary = False)
recognized = []
category = []
for name in specific_name:
    if hasattr(name, 'label'):
        recognized.append(' '.join([w[0] for w in name]))
        category.append(name.label())
named_entity  = list(set(zip(recognized, category)))

# %%
dataframe_entity = pd.DataFrame(named_entity)

# %%
dataframe_entity.columns = ['Indian_BJP_Entities','Labels']

# %%
dataframe_entity
# Out:
#                          Indian_BJP_Entities        Labels
# 0                                     Telugu           GPE
# 1                               Jayalalithaa  ORGANIZATION
# 2                                 Opposition  ORGANIZATION
# 3                                     Indian           GPE
# 4                                        MGR  ORGANIZATION
# 5                                 Parliament  ORGANIZATION
# 6                                    Jayaram        PERSON
# 7                                     Leader  ORGANIZATION
# 8                                      India           GPE
# 9                                      Tamil           GPE
# 10                                 Dravidian           GPE
# 11                              Tamil Cinema        PERSON
# 12                                   Kannada           GPE
# 13                               Karunanidhi           GPE
# 14                                Tamil Nadu        PERSON
# 15                      Atal Bihari Vajpayee        PERSON
# 16                                    AIADMK  ORGANIZATION
# 17                       Janaki Ramachandran        PERSON
# 18                               Rajya Sabha  ORGANIZATION
# 19                               Karunanidhi        PERSON
# 20                         Puratchi Thalaivi        PERSON
# 21  All India Anna Dravida Munnetra Kazhagam  ORGANIZATION
# 22                              Jayalalithaa        PERSON

# %%
dataframe_entity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Indian_BJP_Entities  23 non-null     object
#  1   Labels               23 non-null     object
# dtypes: object(2)
# memory usage: 496.0+ bytes

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
word = nlp(data)

# %%
entit = []
lab =[]

for w in word.ents:
    print(w.text,w.label_)
    entit.append(w.text)
    lab.append(w.label_)
df_ent = list(set(zip(entit,lab)))
# Out:
# Jayaram ORG
# 24 February 1948 DATE
# Indian NORP
# six CARDINAL
# Tamil Nadu ORG
# fourteen years DATE
# between 1991 and 2016 DATE
# 9 February 1989 DATE
# AIADMK ORG
# Dravidian NORP
# Puratchi Thalaivi PERSON
# AIADMK ORG
# first ORDINAL
# the mid-1960s DATE
# Jayalalithaa PERSON
# 140 CARDINAL
# between 1961 and 1980 DATE
# Kannada PERSON
# Jayalalithaa PERSON
# Queen of Tamil Cinema".[4] WORK_OF_ART
# M. G. Ramachandran PERSON
# Tamil GPE
# 1982 DATE
# MGR ORG
# Jayalalithaa PERSON
# AIADMK ORG
# a few years DATE
# AIADMK ORG
# Rajya Sabha PERSON
# India GPE
# Parliament ORG
# MGR ORG
# 1987 DATE
# Jayalalithaa ORG
# Janaki Ramachandran PERSON
# MGR ORG
# AIADMK ORG
# 1989 DATE
# Leader of the Opposition to the DMK ORG
# Karunanidhi PERSON
# 1991 DATE
# Tamil Nadu's PERSON
# first ORDINAL
# Jayalalithaa ORG
# 1995 DATE
# 1996 DATE
# AIADMK ORG
# Jayalalithaa PERSON
# Karunanidhi PERSON
# 1998 DATE
# AIADMK ORG
# Bihari Vajpayee PERSON
# 1998–99 CARDINAL
# a year later DATE
# AIADMK ORG
# 2001 DATE
# Jayalalithaa PERSON
# a few months DATE
# September 2001 DATE
# O. Panneerselvam PERSON
# six months later DATE
# Jayalalithaa ORG
# midnight TIME
# Jayalalithaa PERSON
# fourth ORDINAL
# AIADMK ORG
# 2011 DATE
# Three years DATE
# May 2015 DATE
# 2016 DATE
# first ORDINAL
# Tamil Nadu ORG
# MGR ORG
# 1984 DATE
# September DATE
# 75 days DATE
# 5 December 2016 DATE

# %%
df_ent = pd.DataFrame(df_ent)
df_ent.columns = ['entity','generated_labels']
df_ent
# Out:
#                                  entity generated_labels
# 0            Queen of Tamil Cinema".[4]      WORK_OF_ART
# 1                             Dravidian             NORP
# 2                                  1982             DATE
# 3                       Bihari Vajpayee           PERSON
# 4                          Jayalalithaa              ORG
# 5                             September             DATE
# 6                                   MGR              ORG
# 7                                  1998             DATE
# 8                            Parliament              ORG
# 9                          Tamil Nadu's           PERSON
# 10                              1998–99         CARDINAL
# 11                                 1984             DATE
# 12                   M. G. Ramachandran           PERSON
# 13                                India              GPE
# 14                                 2001             DATE
# 15                          Three years             DATE
# 16                          Rajya Sabha           PERSON
# 17                                Tamil              GPE
# 18                                  six         CARDINAL
# 19                     O. Panneerselvam           PERSON
# 20                           Tamil Nadu              ORG
# 21                between 1991 and 2016             DATE
# 22                          a few years             DATE
# 23                     six months later             DATE
# 24                       September 2001             DATE
# 25                               Indian             NORP
# 26                               fourth          ORDINAL
# 27                between 1961 and 1980             DATE
# 28                         a year later             DATE
# 29                                first          ORDINAL
# 30                         a few months             DATE
# 31                             May 2015             DATE
# 32                       fourteen years             DATE
# 33                                 1995             DATE
# 34                        the mid-1960s             DATE
# 35                      9 February 1989             DATE
# 36                                 2011             DATE
# 37                              Kannada           PERSON
# 38                               AIADMK              ORG
# 39                                 1987             DATE
# 40                              75 days             DATE
# 41                                 1996             DATE
# 42                  Janaki Ramachandran           PERSON
# 43                              Jayaram              ORG
# 44                                 1991             DATE
# 45  Leader of the Opposition to the DMK              ORG
# 46                             midnight             TIME
# 47                                 1989             DATE
# 48                                 2016             DATE
# 49                          Karunanidhi           PERSON
# 50                      5 December 2016             DATE
# 51                    Puratchi Thalaivi           PERSON
# 52                     24 February 1948             DATE
# 53                         Jayalalithaa           PERSON
# 54                                  140         CARDINAL

# %%
spacy.explain('CARDINAL')
# Out:
# 'Numerals that do not fall under another type'

# %%
displacy.render(word,style = 'ent', jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jayaram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Jayalalithaa[a] (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24 February 1948
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  – 5 December 2016) was an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  politician and film actress who served
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  times as the Chief Minister of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tamil Nadu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fourteen years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 1991 and 2016
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . From
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9 February 1989
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , she was the general secretary of the All India Anna Dravida Munnetra Kazhagam (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AIADMK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), a
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dravidian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  party whose cadre revered her as their &quot;Amma&quot; (mother) and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Puratchi Thalaivi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (revolutionary leader). Her critics in the media and the opposition accused her of fostering a personality cult and of demanding absolute loyalty from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AIADMK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  legislators and ministers, who often publicly prostrated themselves before her.[3]</br></br>Jayalalithaa
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  came into prominence as a leading film actress in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the mid-1960s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Though she had entered the profession reluctantly, upon the urging of her mother to support the family,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jayalalithaa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  worked prolifically. She appeared in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     140
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  films
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 1961 and 1980
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , primarily in the Tamil, Telugu and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kannada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  languages.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jayalalithaa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  received praise for her versatility as an actress and for her dancing skills, earning the sobriquet &quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Queen of Tamil Cinema&quot;.[4]
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  Among her frequent co-stars was
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     M. G. Ramachandran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tamil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  cultural icon who leveraged his immense popularity with the masses into a successful political career. In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25
